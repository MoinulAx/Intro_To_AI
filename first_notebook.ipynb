# %%
print("hello world")
# Out:
# hello world

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #Bar Graph

# %%
bar_labels=['a','b','c','d']
bar_heights=[3,4,7,2]
plt.bar(bar_labels,bar_heights)
plt.show()

# %% [markdown]
# #Scatter Graph

# %%
x=[1,2,3,4,5,6]
y=[7,8,9,10,11,12]

plt.scatter(x,y)
plt.show()
